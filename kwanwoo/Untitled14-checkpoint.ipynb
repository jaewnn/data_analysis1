# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
train1 = pd.read_csv('C:/Users/82106/Desktop/2022/dacon/train1.csv')

# %%
print(train1['income_total'].max())
# Out:
# 1575000.0

# %%
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'income_total', shade=True)
facet.set(xlim=(0, train1['income_total'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'child_num', shade=True)
facet.set(xlim=(0, train1['child_num'].max()))
facet.add_legend()

# %%
# Out:
# Skewness:2.852

# %%
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'DAYS_BIRTH', shade=True)
facet.set(xlim=(train1['DAYS_BIRTH'].min(), train1['DAYS_BIRTH'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'DAYS_EMPLOYED', shade=True)
facet.set(xlim=(0, train1['DAYS_EMPLOYED'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'begin_month', shade=True)
facet.set(xlim=(0, 40))
facet.add_legend()

# %%
data = pd.read_csv('C:/Users/82106/Desktop/2022/dacon/cortrain.csv')

# %%
plt.figure(figsize=(4.5,4.5))
sns.heatmap(data=data.corr(),annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
train1['log_income_total']=np.log1p(train1['income_total'])
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'log_income_total', shade=True)
facet.set(xlim=(train1['log_income_total'].min(), train1['log_income_total'].max()))
facet.add_legend()

train1['log_child_num']=np.log1p(train1['child_num']+1)
print("Skewness:{:.3f}".format(train1['child_num'].skew()))
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'log_child_num', shade=True)
facet.set(xlim=(train1['log_child_num'].min(), train1['log_child_num'].max()))
facet.add_legend()

train1['log_DAYS_BIRTH']=np.log1p(train1['DAYS_BIRTH'])
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'log_DAYS_BIRTH', shade=True)
facet.set(xlim=(train1['log_DAYS_BIRTH'].min(), train1['log_DAYS_BIRTH'].max()))
facet.add_legend()

train1['log_DAYS_EMPLOYED']=np.log1p(train1['DAYS_EMPLOYED']+1)
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'log_DAYS_EMPLOYED', shade=True)
facet.set(xlim=(0, train1['log_DAYS_EMPLOYED'].max()))
facet.add_legend()

train1['log_family_size']=np.log1p(train1['family_size'])
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'log_family_size', shade=True)
facet.set(xlim=(train1['log_family_size'].min(), train1['log_family_si
                                                        
                                                        ze'].max()))
facet.add_legend()

train1['log_begin_month']=np.log1p(train1['begin_month']+1)
facet = sns.FacetGrid(train1, hue="credit", aspect=4)
facet.map(sns.kdeplot,'log_begin_month', shade=True)
facet.set(xlim=(train1['log_begin_month'].min(),train1['log_begin_month'].max() ))
facet.add_legend()
# Out:
# Skewness:2.852

# %%
# Out:
#        log_income_total  log_child_num  log_DAYS_BIRTH  log_DAYS_EMPLOYED  \
# 0             12.218500       0.693147        9.539644           8.457655
# 1             12.419170       1.098612        9.339701           7.340836
# 2             13.017005       0.693147        9.856815           8.397508
# 3             12.218500       0.693147        9.621721           7.646831
# 4             11.967187       0.693147        9.618336           7.653020
# ...                 ...            ...             ...                ...
# 26452         12.323860       1.386294        9.399306           7.593878
# 26453         12.100718       1.098612        9.635085           7.814803
# 26454         12.586223       0.693147        9.218606           7.609367
# 26455         12.049425       0.693147        9.224835           4.691348
# 26456         11.302217       0.693147        9.881753           6.922644
#
#        log_family_size  log_begin_month
# ...

# %%
plt.figure(figsize=(4.5,4.5))
sns.heatmap(data=train1.iloc[:,-7:].corr(),annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>
